# %%
# we will work through this distil.pub article about momentum: 
# https://distill.pub/2017/momentum/

# %%
import torch
from torch import Tensor
from jaxtyping import Bool, Float, jaxtyped

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# take a simple quadratic convex function
# create a symmetric and invertible A matrix


n = 2
m = 4
A = torch.tensor([[1, 2], [2, 3]])
b = torch.tensor([1, 2])


def quad(x: Float[Tensor, ""]):
    return 1 / 2 * x.t() @ A @ x - b.t() @ x
